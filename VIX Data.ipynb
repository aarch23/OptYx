# %%
import pandas as pd
import numpy as np 
from pathlib import Path

# %%
# convert vix 30 min Jan data from a txt file into a csv

vix_jan_raw = pd.read_csv("vix_30x_202201.txt")
vix_jan_raw.to_csv("vix_30x_202201.csv", index=None)

# %%
vix_feb_raw = pd.read_csv("vix_30x_202202.txt")
vix_feb_raw.to_csv("vix_30x_202202.csv", index=None)

# %%
vix_mar_raw = pd.read_csv("vix_30x_202203.txt")
vix_mar_raw.to_csv("vix_30x_202203.csv", index=None)

# %%
vix_raw_data = pd.concat([vix_jan_raw, vix_feb_raw, vix_mar_raw])

# %%
vix_raw_data
# Out:
#         [QUOTE_UNIXTIME]   [QUOTE_READTIME]  [QUOTE_DATE]  \
# 0             1641220210   2022-01-03 09:30    2022-01-03
# 1             1641220210   2022-01-03 09:30    2022-01-03
# 2             1641220210   2022-01-03 09:30    2022-01-03
# 3             1641220210   2022-01-03 09:30    2022-01-03
# 4             1641220210   2022-01-03 09:30    2022-01-03
# ...                  ...                ...           ...
# 184186        1648756800   2022-03-31 16:00    2022-03-31
# 184187        1648756800   2022-03-31 16:00    2022-03-31
# 184188        1648756800   2022-03-31 16:00    2022-03-31
# 184189        1648756800   2022-03-31 16:00    2022-03-31
# 184190        1648756800   2022-03-31 16:00    2022-03-31
#
#          [QUOTE_TIME_HOURS]   [UNDERLYING_LAST]  [EXPIRE_DATE]  \
# 0                       9.5               17.68     2022-01-05
# 1                       9.5               17.68     2022-01-05
# 2                       9.5               17.68     2022-01-05
# ...

# %%
# drop the puts columns

vix_raw_data.drop(vix_raw_data.iloc[:, 20:31], inplace = True , axis=1)

vix_raw_data.head()
# Out:
#    [QUOTE_UNIXTIME]   [QUOTE_READTIME]  [QUOTE_DATE]   [QUOTE_TIME_HOURS]  \
# 0        1641220210   2022-01-03 09:30    2022-01-03                  9.5
# 1        1641220210   2022-01-03 09:30    2022-01-03                  9.5
# 2        1641220210   2022-01-03 09:30    2022-01-03                  9.5
# 3        1641220210   2022-01-03 09:30    2022-01-03                  9.5
# 4        1641220210   2022-01-03 09:30    2022-01-03                  9.5
#
#     [UNDERLYING_LAST]  [EXPIRE_DATE]   [EXPIRE_UNIX]   [DTE]   [C_DELTA]  \
# 0               17.68     2022-01-05      1641416400    2.27         1.0
# 1               17.68     2022-01-05      1641416400    2.27         1.0
# 2               17.68     2022-01-05      1641416400    2.27         1.0
# 3               17.68     2022-01-05      1641416400    2.27         1.0
# 4               17.68     2022-01-05      1641416400    2.27         1.0
#
#     [C_GAMMA]   [C_VEGA]   [C_THETA]   [C_RHO]  [C_IV]  [C_VOLUME]   [C_LAST]  \
# ...

# %%
#vix_raw_data.drop(vix_raw_data.columns.difference([' [UNDERLYING_LAST]', '']), 1, inplace=True)

# %%
# Out:
#          [UNDERLYING_LAST]
# 0                    17.68
# 1                    17.68
# 2                    17.68
# 3                    17.68
# 4                    17.68
# ...                    ...
# 184186               21.06
# 184187               21.06
# 184188               21.06
# 184189               21.06
# 184190               21.06
#
# [510601 rows x 1 columns]
