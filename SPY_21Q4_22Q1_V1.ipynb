# %% [markdown]
# # __ADDING Q4 2021__

# %%
import pandas as pd 
import numpy as np 
from pathlib import Path

# %%
spy_oct = pd.read_csv("spy_30x_202110.txt")
#spy_oct.to_csv("spy_30x_202110.csv", index=None)

# %%
spy_nov = pd.read_csv("spy_30x_202111.txt")
#spy_nov.to_csv("spy_30x_202111.csv", index=None)

# %%
spy_dec = pd.read_csv("spy_30x_202112.txt")
#spy_dec.to_csv("spy_30x_202112.csv", index=None)

# %%
spy_2021 = pd.concat([spy_oct, spy_nov, spy_dec], axis=0)

# %%
spy_2021.columns

# %%
#spy_add = spy_2021.loc[' [STRIKE_DISTANCE]']

# %%
spy_2021.drop(columns = [' [P_BID]',' [P_ASK]', ' [P_SIZE]', ' [P_LAST]', ' [P_DELTA]', ' [P_GAMMA]',' [P_VEGA]', ' [P_THETA]', ' [P_RHO]', ' [P_IV]', ' [P_VOLUME]'], inplace = True, axis=1)

# %%
spy_2021.head()

# %%
spy_2021.rename(columns = {' [QUOTE_READTIME]': 'QUOTE_READTIME',' [UNDERLYING_LAST]': 'UNDERLYING_LAST', ' [EXPIRE_DATE]' : 'EXPIRE_DATE', ' [DTE]': 'DTE', ' [C_DELTA]' : 'C_DELTA', ' [C_GAMMA]' : 'C_GAMMA', ' [C_VEGA]': 'C_VEGA', ' [C_THETA]': 'C_THETA', ' [C_RHO]': 'C_RHO', ' [C_IV]': 'C_IV', ' [C_VOLUME]': 'C_VOLUME', ' [C_LAST]': 'C_LAST', ' [STRIKE]': 'STRIKE', ' [STRIKE_DISTANCE]': 'STRIKE_DISTANCE', ' [STRIKE_DISTANCE_PCT]': 'STRIKE_DISTANCE_PCT'}, inplace = True)

# %%
spy_2021.columns

# %%
spy_2021.drop(columns=[ ' [QUOTE_DATE]' , ' [QUOTE_TIME_HOURS]', ' [EXPIRE_UNIX]', ' [C_SIZE]', ' [C_BID]', ' [C_ASK]'], inplace = True, axis=1)

# %%
spy_2021.head()

# %%
spy_2021['STRIKE DISTANCE'] = spy_2021['STRIKE'] - spy_2021['UNDERLYING_LAST']

display(spy_2021.tail())

# %%
spy_2021_v2 = spy_2021.drop(columns=['STRIKE_DISTANCE'])
spy_2021_v2.head()

# %%
spy_2021_v2['CONTRACT'] = spy_2021_v2['STRIKE'].astype(str) + spy_2021_v2['EXPIRE_DATE']
spy_2021_v2

# %%
spy_2021_v3 = spy_2021_v2.drop(columns=['[QUOTE_UNIXTIME]'])

# %%
spy_2021_v4 = spy_2021_v3.loc[spy_2021_v3['DTE'] <= 5]

# %%
spy_2021_v4

# %%
inception2 = spy_2021_v4[(spy_2021_v4['STRIKE DISTANCE'] <= 15.00) & (spy_2021_v4['STRIKE DISTANCE'] > -3.00)]
inception2

# %%
inception_filtered2 = inception2.loc[inception2['DTE'] == 4.27]
inception_filtered2

# %%
#inception_filtered3 = inception_filtered2.reset_index()

# %%
#inception_filtered3

# %%
criteria_list2 = inception_filtered2['CONTRACT']

# %%
criteria_list2.count()

# %%
#spy_2021_v5 = spy_2021_v4.reset_index()

# %%
spy_2021_v4.tail()

# %%
spy_2021calls = spy_2021_v4[spy_2021_v4["CONTRACT"].isin(criteria_list2)]

# %%
spy_2021calls.count()

# %%
spy_2021calls.iloc[4673]

# %%
spy_2021calls['C_IV'] = pd.to_numeric(spy_2021calls['C_IV'], errors = 'coerce')
spy_2021calls['C_LAST'] = pd.to_numeric(spy_2021calls['C_LAST'], errors = 'coerce')
spy_2021calls['C_VOLUME'] = pd.to_numeric(spy_2021calls['C_VOLUME'], errors = 'coerce')

# %%
spy_2021calls

# %%
spy_2021calls.to_csv("spy_2021callsv1.csv", index=None)

# %% [markdown]
# # __START HERE to calculate 'y' and filter DTE__

# %%
import pandas as pd 
import numpy as np 
from pathlib import Path

# %%
spy_path = Path('spy_2021callsv1.csv')
spy_21_q4 = pd.read_csv(spy_path)

# %%
spy_21_q4 = spy_21_q4.set_index('CONTRACT')

# %%
spy_21_q4["PRICECLOSE"] = spy_21_q4.loc[spy_21_q4['DTE'] == 2.0, 'C_LAST']
spy_21_q4.head()

# %%
spy_21_q4['ROI3'] = spy_21_q4["PRICECLOSE"] / spy_21_q4['C_LAST']
spy_21_q4.head()

# %%
spy_21_q4['ROI %'] = (spy_21_q4['ROI3'] - 1) * 100
spy_21_q4.head(100)

# %%
spy_21_q4 = spy_21_q4.drop(columns=['ROI3'])
spy_21_q4.head()

# %%
#APPROACH A: 6 categories

#spy_21_q4.loc[spy_21_q4["ROI %"] <= -60, "y"] = 0
#spy_21_q4.loc[(spy_21_q4["ROI %"] <= -10) & (spy_21_q4["ROI %"] > -60), "y"] = 1
#spy_21_q4.loc[(spy_21_q4["ROI %"] <= 10) & (spy_21_q4["ROI %"] > -10), "y"] = 2
#spy_21_q4.loc[(spy_21_q4["ROI %"] <= 60) & (spy_21_q4["ROI %"] > 10), "y"] = 3
#spy_21_q4.loc[(spy_21_q4["ROI %"] > 60) & (spy_21_q4["ROI %"] < 100), "y"] = 4
#spy_21_q4.loc[spy_21_q4["ROI %"] >= 100, "y"] = 5

# %%
#APPROACH B: 3 categories 

spy_21_q4.loc[spy_21_q4["ROI %"] <= -30, "y"] = 0

spy_21_q4.loc[(spy_21_q4["ROI %"] <= 25) & (spy_21_q4["ROI %"] > -30), "y"] = 1

spy_21_q4.loc[spy_21_q4["ROI %"] > 25, "y"] = 2

# %%
spy_21_q4["y"].value_counts()

# %%
spy_21_q4.rename(columns = {'UNDERLYING_LAST': 'SPY PRICE'}, inplace = True)
spy_21_q4.head()

# %%
spy_21_q4.reset_index(inplace=True)

# %%
spy_21_q4 = spy_21_q4.set_index('QUOTE_READTIME')
spy_21_q4.head()

# %%
spy_21_q4.index = pd.to_datetime(spy_21_q4.index, infer_datetime_format=True)
spy_21_q4.head()

# %%
#Drops all rows after DTE2.0

spy_21_q4_filt = spy_21_q4.loc[(spy_21_q4["DTE"]<=4.27) & (spy_21_q4["DTE"]>=2.0)]

# %%
spy_21_q4_filt.shape

# %%
spy_21_q4_filt = spy_21_q4_filt.dropna()

# %%
spy_21_q4_filt.shape

# %%
spy_21_q4_filt.to_csv("./Resources/spy_21_q4_filt.csv", index=True)

# %% [markdown]
# # __START HERE to concat with Q1 2022, *Inflation included* (missing VIX, Sentiment)__

# %%
import pandas as pd 
import numpy as np 
from pathlib import Path

# %%
#Importing 2021 Q4 with Inflation (version that does NOT include VIX and Sentiment)

spy_path = Path('./Resources/spy_21_q4_inf.csv')
spy_21_q4_filt = pd.read_csv(spy_path)
spy_21_q4_filt.set_index(["QUOTE_READTIME"], inplace=True)
print(spy_21_q4_filt.shape)
spy_21_q4_filt.head()

# %%
#Importing 2022 Q1 (version that does NOT include VIX and Sentiment)

spy_path = Path('./Resources/spy_22_q1_filt.csv')
spy_22_q1_filt = pd.read_csv(spy_path)
spy_22_q1_filt.set_index(["QUOTE_READTIME"], inplace=True)
print(spy_22_q1_filt.shape)
spy_22_q1_filt.head()

# %%
q4_21_q1_22 = pd.concat([spy_21_q4_filt, spy_22_q1_filt])

# %%
print(q4_21_q1_22.shape)
q4_21_q1_22

# %%
q4_21_q1_22 = q4_21_q1_22.dropna()
q4_21_q1_22.shape

# %%
#APPROACH B: 3 categories 

q4_21_q1_22.loc[q4_21_q1_22["ROI %"] <= -30, "y"] = 0

q4_21_q1_22.loc[(q4_21_q1_22["ROI %"] <= 25) & (q4_21_q1_22["ROI %"] > -30), "y"] = 1

q4_21_q1_22.loc[q4_21_q1_22["ROI %"] > 25, "y"] = 2

# %%
q4_21_q1_22.head(50)

# %%
q4_21_q1_22.to_csv("./Resources/q4_21_q1_22.csv", index=True)

# %% [markdown]
# # __START HERE 07/09 to add VIX__

# %%
import pandas as pd 
import numpy as np 
from pathlib import Path

# %%
# Importing Vix Data 

vix_path = Path('./Resources/vixpriceQ4.csv')
vix_df = pd.read_csv(vix_path)
vix_df
# Out:
#       [QUOTE_READTIME]   [UNDERLYING_LAST]
# 0     2021-10-01 09:30               22.44
# 1     2021-10-01 10:00               22.91
# 2     2021-10-01 10:30               23.15
# 3     2021-10-01 11:00               22.66
# 4     2021-10-01 11:30               22.21
# ..                 ...                 ...
# 889   2021-12-31 14:00               17.32
# 890   2021-12-31 14:30               17.34
# 891   2021-12-31 15:00               17.40
# 892   2021-12-31 15:30               17.13
# 893   2021-12-31 16:00               17.54
#
# [894 rows x 2 columns]

# %%
vix_df.rename(columns = {'[QUOTE_READTIME]': 'QUOTE_READTIME',' [UNDERLYING_LAST]': 'VIX PRICE'}, inplace = True)

# %%
vix_df1 = vix_df.drop_duplicates()
vix_df1.head()
# Out:
#       QUOTE_READTIME  VIX PRICE
# 0   2021-10-01 09:30      22.44
# 1   2021-10-01 10:00      22.91
# 2   2021-10-01 10:30      23.15
# 3   2021-10-01 11:00      22.66
# 4   2021-10-01 11:30      22.21

# %%
vix_df1 = vix_df1.set_index('QUOTE_READTIME')

# %%
vix_df1.index = pd.to_datetime(vix_df1.index, infer_datetime_format=True)
vix_df1
# Out:
#                      VIX PRICE
# QUOTE_READTIME
# 2021-10-01 09:30:00      22.44
# 2021-10-01 10:00:00      22.91
# 2021-10-01 10:30:00      23.15
# 2021-10-01 11:00:00      22.66
# 2021-10-01 11:30:00      22.21
# ...                        ...
# 2021-12-31 14:00:00      17.32
# 2021-12-31 14:30:00      17.34
# 2021-12-31 15:00:00      17.40
# 2021-12-31 15:30:00      17.13
# 2021-12-31 16:00:00      17.54
#
# [894 rows x 1 columns]

# %%
path = Path('./Resources/q4_21_q1_22.csv')
q4_21_q1_22 = pd.read_csv(path)
q4_21_q1_22
# Out:
#             QUOTE_READTIME          CONTRACT  SPY PRICE  EXPIRE_DATE   DTE  \
# 0           10/4/2021 9:30  430.0 2021-10-08     432.95   2021-10-08  4.27
# 1           10/4/2021 9:30  431.0 2021-10-08     432.95   2021-10-08  4.27
# 2           10/4/2021 9:30  432.0 2021-10-08     432.95   2021-10-08  4.27
# 3           10/4/2021 9:30  433.0 2021-10-08     432.95   2021-10-08  4.27
# 4           10/4/2021 9:30  434.0 2021-10-08     432.95   2021-10-08  4.27
# ...                    ...               ...        ...          ...   ...
# 18281  2022-03-23 16:00:00  455.0 2022-03-25     443.84    3/25/2022  2.00
# 18282  2022-03-23 16:00:00  456.0 2022-03-25     443.84    3/25/2022  2.00
# 18283  2022-03-23 16:00:00  457.0 2022-03-25     443.84    3/25/2022  2.00
# 18284  2022-03-23 16:00:00  458.0 2022-03-25     443.84    3/25/2022  2.00
# 18285  2022-03-23 16:00:00  459.0 2022-03-25     443.84    3/25/2022  2.00
#
#        C_DELTA  C_GAMMA   C_VEGA  C_THETA    C_RHO     C_IV  C_VOLUME  C_LAST  \
# 0      0.61310  0.03556  0.19356 -0.43339  0.03538  0.21263        10    5.93
# 1      0.57914  0.03730  0.19781 -0.43196  0.03344  0.20709         1    5.21
# 2      0.54144  0.03858  0.20139 -0.43035  0.03157  0.20271         0    5.61
# 3      0.50267  0.03978  0.20224 -0.42316  0.02886  0.19849         1    4.01
# 4      0.46199  0.04063  0.20081 -0.41040  0.02677  0.19261        13    3.42
# ...        ...      ...      ...      ...      ...      ...       ...     ...
# 18281  0.04696  0.01493  0.03746 -0.09216  0.00106  0.17010     12879    0.13
# 18282  0.03309  0.01144  0.02826 -0.06611  0.00075  0.16963     10707    0.09
# 18283  0.02264  0.00839  0.02085 -0.04539  0.00083  0.16879      4434    0.05
# 18284  0.01819  0.00688  0.01736 -0.03784  0.00030  0.17380      4001    0.04
# 18285  0.01514  0.00542  0.01463 -0.03065  0.00091  0.17742      2672    0.03
#
#        STRIKE  STRIKE_DISTANCE_PCT  STRIKE DISTANCE  PRICECLOSE      ROI %  \
# 0       430.0                0.007            -2.95        6.11   3.035413
# 1       431.0                0.004            -1.95        5.31   1.919386
# 2       432.0                0.002            -0.95        4.63 -17.468806
# 3       433.0                0.000             0.05        3.95  -1.496259
# 4       434.0                0.002             1.05        3.22  -5.847953
# ...       ...                  ...              ...         ...        ...
# 18281   455.0                0.025            11.16        0.13   0.000000
# 18282   456.0                0.027            12.16        0.09   0.000000
# 18283   457.0                0.030            13.16        0.05   0.000000
# 18284   458.0                0.032            14.16        0.04   0.000000
# 18285   459.0                0.034            15.16        0.03   0.000000
#
#          y  INFLATION%
# 0      1.0         0.3
# 1      1.0         0.3
# 2      1.0         0.3
# 3      1.0         0.3
# 4      1.0         0.3
# ...    ...         ...
# 18281  1.0         0.8
# 18282  1.0         0.8
# 18283  1.0         0.8
# 18284  1.0         0.8
# 18285  1.0         0.8
#
# [18286 rows x 20 columns]

# %%
q4_21_q1_22 = q4_21_q1_22.set_index('QUOTE_READTIME')

# %%
q4_21_q1_22 .index = pd.to_datetime(q4_21_q1_22 .index, infer_datetime_format=True)
q4_21_q1_22
# Out:
#                              CONTRACT  SPY PRICE  EXPIRE_DATE   DTE  C_DELTA  \
# QUOTE_READTIME
# 2021-10-04 09:30:00  430.0 2021-10-08     432.95   2021-10-08  4.27  0.61310
# 2021-10-04 09:30:00  431.0 2021-10-08     432.95   2021-10-08  4.27  0.57914
# 2021-10-04 09:30:00  432.0 2021-10-08     432.95   2021-10-08  4.27  0.54144
# 2021-10-04 09:30:00  433.0 2021-10-08     432.95   2021-10-08  4.27  0.50267
# 2021-10-04 09:30:00  434.0 2021-10-08     432.95   2021-10-08  4.27  0.46199
# ...                               ...        ...          ...   ...      ...
# 2022-03-23 16:00:00  455.0 2022-03-25     443.84    3/25/2022  2.00  0.04696
# 2022-03-23 16:00:00  456.0 2022-03-25     443.84    3/25/2022  2.00  0.03309
# 2022-03-23 16:00:00  457.0 2022-03-25     443.84    3/25/2022  2.00  0.02264
# 2022-03-23 16:00:00  458.0 2022-03-25     443.84    3/25/2022  2.00  0.01819
# 2022-03-23 16:00:00  459.0 2022-03-25     443.84    3/25/2022  2.00  0.01514
#
#                      C_GAMMA   C_VEGA  C_THETA    C_RHO     C_IV  C_VOLUME  \
# QUOTE_READTIME
# 2021-10-04 09:30:00  0.03556  0.19356 -0.43339  0.03538  0.21263        10
# 2021-10-04 09:30:00  0.03730  0.19781 -0.43196  0.03344  0.20709         1
# 2021-10-04 09:30:00  0.03858  0.20139 -0.43035  0.03157  0.20271         0
# 2021-10-04 09:30:00  0.03978  0.20224 -0.42316  0.02886  0.19849         1
# 2021-10-04 09:30:00  0.04063  0.20081 -0.41040  0.02677  0.19261        13
# ...                      ...      ...      ...      ...      ...       ...
# 2022-03-23 16:00:00  0.01493  0.03746 -0.09216  0.00106  0.17010     12879
# 2022-03-23 16:00:00  0.01144  0.02826 -0.06611  0.00075  0.16963     10707
# 2022-03-23 16:00:00  0.00839  0.02085 -0.04539  0.00083  0.16879      4434
# 2022-03-23 16:00:00  0.00688  0.01736 -0.03784  0.00030  0.17380      4001
# 2022-03-23 16:00:00  0.00542  0.01463 -0.03065  0.00091  0.17742      2672
#
#                      C_LAST  STRIKE  STRIKE_DISTANCE_PCT  STRIKE DISTANCE  \
# QUOTE_READTIME
# 2021-10-04 09:30:00    5.93   430.0                0.007            -2.95
# 2021-10-04 09:30:00    5.21   431.0                0.004            -1.95
# 2021-10-04 09:30:00    5.61   432.0                0.002            -0.95
# 2021-10-04 09:30:00    4.01   433.0                0.000             0.05
# 2021-10-04 09:30:00    3.42   434.0                0.002             1.05
# ...                     ...     ...                  ...              ...
# 2022-03-23 16:00:00    0.13   455.0                0.025            11.16
# 2022-03-23 16:00:00    0.09   456.0                0.027            12.16
# 2022-03-23 16:00:00    0.05   457.0                0.030            13.16
# 2022-03-23 16:00:00    0.04   458.0                0.032            14.16
# 2022-03-23 16:00:00    0.03   459.0                0.034            15.16
#
#                      PRICECLOSE      ROI %    y  INFLATION%
# QUOTE_READTIME
# 2021-10-04 09:30:00        6.11   3.035413  1.0         0.3
# 2021-10-04 09:30:00        5.31   1.919386  1.0         0.3
# 2021-10-04 09:30:00        4.63 -17.468806  1.0         0.3
# 2021-10-04 09:30:00        3.95  -1.496259  1.0         0.3
# 2021-10-04 09:30:00        3.22  -5.847953  1.0         0.3
# ...                         ...        ...  ...         ...
# 2022-03-23 16:00:00        0.13   0.000000  1.0         0.8
# 2022-03-23 16:00:00        0.09   0.000000  1.0         0.8
# 2022-03-23 16:00:00        0.05   0.000000  1.0         0.8
# 2022-03-23 16:00:00        0.04   0.000000  1.0         0.8
# 2022-03-23 16:00:00        0.03   0.000000  1.0         0.8
#
# [18286 rows x 19 columns]

# %%
q4_21_q1_22.shape
# Out:
# (18286, 19)

# %%
q4_21_q1_22_vix = q4_21_q1_22.merge(vix_df1, on='QUOTE_READTIME')
q4_21_q1_22_vix.shape
# Out:
# (9047, 20)

# %%
print(q4_21_q1_22_vix.shape)
q4_21_q1_22_vix.head()
# Out:
# (9047, 20)
#                              CONTRACT  SPY PRICE  EXPIRE_DATE   DTE  C_DELTA  \
# QUOTE_READTIME
# 2021-10-04 09:30:00  430.0 2021-10-08     432.95   2021-10-08  4.27  0.61310
# 2021-10-04 09:30:00  431.0 2021-10-08     432.95   2021-10-08  4.27  0.57914
# 2021-10-04 09:30:00  432.0 2021-10-08     432.95   2021-10-08  4.27  0.54144
# 2021-10-04 09:30:00  433.0 2021-10-08     432.95   2021-10-08  4.27  0.50267
# 2021-10-04 09:30:00  434.0 2021-10-08     432.95   2021-10-08  4.27  0.46199
#
#                      C_GAMMA   C_VEGA  C_THETA    C_RHO     C_IV  C_VOLUME  \
# QUOTE_READTIME
# 2021-10-04 09:30:00  0.03556  0.19356 -0.43339  0.03538  0.21263        10
# 2021-10-04 09:30:00  0.03730  0.19781 -0.43196  0.03344  0.20709         1
# 2021-10-04 09:30:00  0.03858  0.20139 -0.43035  0.03157  0.20271         0
# 2021-10-04 09:30:00  0.03978  0.20224 -0.42316  0.02886  0.19849         1
# 2021-10-04 09:30:00  0.04063  0.20081 -0.41040  0.02677  0.19261        13
#
#                      C_LAST  STRIKE  STRIKE_DISTANCE_PCT  STRIKE DISTANCE  \
# QUOTE_READTIME
# 2021-10-04 09:30:00    5.93   430.0                0.007            -2.95
# 2021-10-04 09:30:00    5.21   431.0                0.004            -1.95
# 2021-10-04 09:30:00    5.61   432.0                0.002            -0.95
# 2021-10-04 09:30:00    4.01   433.0                0.000             0.05
# 2021-10-04 09:30:00    3.42   434.0                0.002             1.05
#
#                      PRICECLOSE      ROI %    y  INFLATION%  VIX PRICE
# QUOTE_READTIME
# 2021-10-04 09:30:00        6.11   3.035413  1.0         0.3      22.25
# 2021-10-04 09:30:00        5.31   1.919386  1.0         0.3      22.25
# 2021-10-04 09:30:00        4.63 -17.468806  1.0         0.3      22.25
# 2021-10-04 09:30:00        3.95  -1.496259  1.0         0.3      22.25
# 2021-10-04 09:30:00        3.22  -5.847953  1.0         0.3      22.25

# %%
q4_21_q1_22_vix.to_csv("./Resources/q4_21_q1_22_vix.csv", index=True)

# %% [markdown]
# # __START HERE 07/06 to select certain ranges of train/test data instead of random train/test/split__

# %%
import pandas as pd 
import numpy as np 
from pathlib import Path

# %%
spy_path = Path('./Resources/q4_21_q1_22_vix.csv')
df = pd.read_csv(spy_path)
df
# Out:
#            QUOTE_READTIME          CONTRACT  SPY PRICE  EXPIRE_DATE   DTE  \
# 0     2021-10-04 09:30:00  430.0 2021-10-08     432.95   2021-10-08  4.27
# 1     2021-10-04 09:30:00  431.0 2021-10-08     432.95   2021-10-08  4.27
# 2     2021-10-04 09:30:00  432.0 2021-10-08     432.95   2021-10-08  4.27
# 3     2021-10-04 09:30:00  433.0 2021-10-08     432.95   2021-10-08  4.27
# 4     2021-10-04 09:30:00  434.0 2021-10-08     432.95   2021-10-08  4.27
# ...                   ...               ...        ...          ...   ...
# 9042  2021-12-29 16:00:00  483.0 2021-12-31     477.48   2021-12-31  2.00
# 9043  2021-12-29 16:00:00  484.0 2021-12-31     477.48   2021-12-31  2.00
# 9044  2021-12-29 16:00:00  485.0 2021-12-31     477.48   2021-12-31  2.00
# 9045  2021-12-29 16:00:00  486.0 2021-12-31     477.48   2021-12-31  2.00
# 9046  2021-12-29 16:00:00  487.0 2021-12-31     477.48   2021-12-31  2.00
#
#       C_DELTA  C_GAMMA   C_VEGA  C_THETA    C_RHO  ...  C_VOLUME  C_LAST  \
# 0     0.61310  0.03556  0.19356 -0.43339  0.03538  ...        10    5.93
# 1     0.57914  0.03730  0.19781 -0.43196  0.03344  ...         1    5.21
# 2     0.54144  0.03858  0.20139 -0.43035  0.03157  ...         0    5.61
# 3     0.50267  0.03978  0.20224 -0.42316  0.02886  ...         1    4.01
# 4     0.46199  0.04063  0.20081 -0.41040  0.02677  ...        13    3.42
# ...       ...      ...      ...      ...      ...  ...       ...     ...
# 9042  0.07746  0.03704  0.05983 -0.08835  0.00294  ...     10517    0.14
# 9043  0.05140  0.02616  0.04388 -0.06105  0.00162  ...      6389    0.09
# 9044  0.03414  0.01829  0.03162 -0.04283  0.00111  ...     14034    0.06
# 9045  0.02645  0.01408  0.02574 -0.03567  0.00078  ...      3114    0.05
# 9046  0.02102  0.01072  0.02131 -0.02870  0.00111  ...      2626    0.03
#
#       STRIKE  STRIKE_DISTANCE_PCT  STRIKE DISTANCE  PRICECLOSE      ROI %  \
# 0      430.0                0.007            -2.95        6.11   3.035413
# 1      431.0                0.004            -1.95        5.31   1.919386
# 2      432.0                0.002            -0.95        4.63 -17.468806
# 3      433.0                0.000             0.05        3.95  -1.496259
# 4      434.0                0.002             1.05        3.22  -5.847953
# ...      ...                  ...              ...         ...        ...
# 9042   483.0                0.012             5.52        0.14   0.000000
# 9043   484.0                0.014             6.52        0.09   0.000000
# 9044   485.0                0.016             7.52        0.06   0.000000
# 9045   486.0                0.018             8.52        0.05   0.000000
# 9046   487.0                0.020             9.52        0.03   0.000000
#
#         y  INFLATION%  VIX PRICE
# 0     1.0         0.3      22.25
# 1     1.0         0.3      22.25
# 2     1.0         0.3      22.25
# 3     1.0         0.3      22.25
# 4     1.0         0.3      22.25
# ...   ...         ...        ...
# 9042  1.0         0.8      17.04
# 9043  1.0         0.8      17.04
# 9044  1.0         0.8      17.04
# 9045  1.0         0.8      17.04
# 9046  1.0         0.8      17.04
#
# [9047 rows x 21 columns]

# %%
df.shape
# Out:
# (9047, 21)

# %%
test_2qs = df.iloc[6095:9753]
test_2qs
# Out:
#            QUOTE_READTIME          CONTRACT  SPY PRICE  EXPIRE_DATE   DTE  \
# 6095  2021-11-29 14:00:00  477.5 2021-12-03     466.25   2021-12-03  4.08
# 6096  2021-11-29 14:00:00  478.0 2021-12-03     466.25   2021-12-03  4.08
# 6097  2021-11-29 14:00:00  479.0 2021-12-03     466.25   2021-12-03  4.08
# 6098  2021-11-29 14:30:00  462.0 2021-12-03     465.93   2021-12-03  4.06
# 6099  2021-11-29 14:30:00  462.5 2021-12-03     465.93   2021-12-03  4.06
# ...                   ...               ...        ...          ...   ...
# 9042  2021-12-29 16:00:00  483.0 2021-12-31     477.48   2021-12-31  2.00
# 9043  2021-12-29 16:00:00  484.0 2021-12-31     477.48   2021-12-31  2.00
# 9044  2021-12-29 16:00:00  485.0 2021-12-31     477.48   2021-12-31  2.00
# 9045  2021-12-29 16:00:00  486.0 2021-12-31     477.48   2021-12-31  2.00
# 9046  2021-12-29 16:00:00  487.0 2021-12-31     477.48   2021-12-31  2.00
#
#       C_DELTA  C_GAMMA   C_VEGA  C_THETA    C_RHO  ...  C_VOLUME  C_LAST  \
# 6095  0.03813  0.01323  0.04436 -0.04721  0.00247  ...       137    0.09
# 6096  0.03425  0.01197  0.04012 -0.04335  0.00231  ...      1218    0.08
# 6097  0.02334  0.00877  0.02989 -0.03026  0.00188  ...       392    0.05
# 6098  0.66737  0.03894  0.19384 -0.36992  0.04046  ...      3299    6.00
# 6099  0.64929  0.04032  0.19768 -0.37281  0.03856  ...      3272    5.59
# ...       ...      ...      ...      ...      ...  ...       ...     ...
# 9042  0.07746  0.03704  0.05983 -0.08835  0.00294  ...     10517    0.14
# 9043  0.05140  0.02616  0.04388 -0.06105  0.00162  ...      6389    0.09
# 9044  0.03414  0.01829  0.03162 -0.04283  0.00111  ...     14034    0.06
# 9045  0.02645  0.01408  0.02574 -0.03567  0.00078  ...      3114    0.05
# 9046  0.02102  0.01072  0.02131 -0.02870  0.00111  ...      2626    0.03
#
#       STRIKE  STRIKE_DISTANCE_PCT  STRIKE DISTANCE  PRICECLOSE      ROI %  \
# 6095   477.5                0.024            11.25        0.01 -88.888889
# 6096   478.0                0.025            11.75        0.02 -75.000000
# 6097   479.0                0.027            12.75        0.02 -60.000000
# 6098   462.0                0.008            -3.93        0.53 -91.166667
# 6099   462.5                0.007            -3.43        0.45 -91.949911
# ...      ...                  ...              ...         ...        ...
# 9042   483.0                0.012             5.52        0.14   0.000000
# 9043   484.0                0.014             6.52        0.09   0.000000
# 9044   485.0                0.016             7.52        0.06   0.000000
# 9045   486.0                0.018             8.52        0.05   0.000000
# 9046   487.0                0.020             9.52        0.03   0.000000
#
#         y  INFLATION%  VIX PRICE
# 6095  0.0         0.9      22.06
# 6096  0.0         0.9      22.06
# 6097  0.0         0.9      22.06
# 6098  0.0         0.9      22.18
# 6099  0.0         0.9      22.18
# ...   ...         ...        ...
# 9042  1.0         0.8      17.04
# 9043  1.0         0.8      17.04
# 9044  1.0         0.8      17.04
# 9045  1.0         0.8      17.04
# 9046  1.0         0.8      17.04
#
# [2952 rows x 21 columns]

# %%
train1 = df.iloc[:6094]
train1
# Out:
#            QUOTE_READTIME          CONTRACT  SPY PRICE  EXPIRE_DATE   DTE  \
# 0     2021-10-04 09:30:00  430.0 2021-10-08     432.95   2021-10-08  4.27
# 1     2021-10-04 09:30:00  431.0 2021-10-08     432.95   2021-10-08  4.27
# 2     2021-10-04 09:30:00  432.0 2021-10-08     432.95   2021-10-08  4.27
# 3     2021-10-04 09:30:00  433.0 2021-10-08     432.95   2021-10-08  4.27
# 4     2021-10-04 09:30:00  434.0 2021-10-08     432.95   2021-10-08  4.27
# ...                   ...               ...        ...          ...   ...
# 6089  2021-11-29 14:00:00  472.5 2021-12-03     466.25   2021-12-03  4.08
# 6090  2021-11-29 14:00:00  473.0 2021-12-03     466.25   2021-12-03  4.08
# 6091  2021-11-29 14:00:00  474.0 2021-12-03     466.25   2021-12-03  4.08
# 6092  2021-11-29 14:00:00  475.0 2021-12-03     466.25   2021-12-03  4.08
# 6093  2021-11-29 14:00:00  476.0 2021-12-03     466.25   2021-12-03  4.08
#
#       C_DELTA  C_GAMMA   C_VEGA  C_THETA    C_RHO  ...  C_VOLUME  C_LAST  \
# 0     0.61310  0.03556  0.19356 -0.43339  0.03538  ...        10    5.93
# 1     0.57914  0.03730  0.19781 -0.43196  0.03344  ...         1    5.21
# 2     0.54144  0.03858  0.20139 -0.43035  0.03157  ...         0    5.61
# 3     0.50267  0.03978  0.20224 -0.42316  0.02886  ...         1    4.01
# 4     0.46199  0.04063  0.20081 -0.41040  0.02677  ...        13    3.42
# ...       ...      ...      ...      ...      ...  ...       ...     ...
# 6089  0.17502  0.03911  0.13770 -0.17628  0.01047  ...      1167    0.61
# 6090  0.15350  0.03641  0.12664 -0.15786  0.00920  ...      1345    0.51
# 6091  0.11554  0.03051  0.10417 -0.12408  0.00662  ...      4892    0.35
# 6092  0.08496  0.02476  0.08354 -0.09662  0.00526  ...      5179    0.25
# 6093  0.06112  0.01948  0.06458 -0.07197  0.00380  ...      4160    0.16
#
#       STRIKE  STRIKE_DISTANCE_PCT  STRIKE DISTANCE  PRICECLOSE      ROI %  \
# 0      430.0                0.007            -2.95        6.11   3.035413
# 1      431.0                0.004            -1.95        5.31   1.919386
# 2      432.0                0.002            -0.95        4.63 -17.468806
# 3      433.0                0.000             0.05        3.95  -1.496259
# 4      434.0                0.002             1.05        3.22  -5.847953
# ...      ...                  ...              ...         ...        ...
# 6089   472.5                0.013             6.25        0.03 -95.081967
# 6090   473.0                0.014             6.75        0.03 -94.117647
# 6091   474.0                0.017             7.75        0.03 -91.428571
# 6092   475.0                0.019             8.75        0.02 -92.000000
# 6093   476.0                0.021             9.75        0.02 -87.500000
#
#         y  INFLATION%  VIX PRICE
# 0     1.0         0.3      22.25
# 1     1.0         0.3      22.25
# 2     1.0         0.3      22.25
# 3     1.0         0.3      22.25
# 4     1.0         0.3      22.25
# ...   ...         ...        ...
# 6089  0.0         0.9      22.06
# 6090  0.0         0.9      22.06
# 6091  0.0         0.9      22.06
# 6092  0.0         0.9      22.06
# 6093  0.0         0.9      22.06
#
# [6094 rows x 21 columns]

# %%
train2 = df.iloc[9754:]
train2
# Out:
# Empty DataFrame
# Columns: [QUOTE_READTIME, CONTRACT, SPY PRICE, EXPIRE_DATE, DTE, C_DELTA, C_GAMMA, C_VEGA, C_THETA, C_RHO, C_IV, C_VOLUME, C_LAST, STRIKE, STRIKE_DISTANCE_PCT, STRIKE DISTANCE, PRICECLOSE, ROI %, y, INFLATION%, VIX PRICE]
# Index: []
#
# [0 rows x 21 columns]

# %%
train_2qs = pd.concat([train1, train2], axis=0)
print(train_2qs.shape)
# Out:
# (6094, 21)

# %%
train_2qs.to_csv("./Resources/train_2qs.csv", index=None)
test_2qs.to_csv("./Resources/test_2qs.csv", index=None)
