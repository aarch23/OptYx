# %% [markdown]
# ## Skip down to where it says Start Here

# %%
import pandas as pd 
import numpy as np 
from pathlib import Path
import hvplot.pandas
# %matplotlib inline

# %%
spy_feb_raw = pd.read_csv("./Resources/spy_30x_202202.txt")
# spy_feb_raw.to_csv("./Resources/spy_30x_202202.csv", index=None)

# %%
spy_feb_raw.head()

# %%
# Dropping all the PUT columns since it is not needed 

spy_feb_raw.drop(spy_feb_raw.iloc[:, 20:31], inplace = True , axis=1)

spy_feb_raw.tail()

# %%
spy_jan_raw = pd.read_csv("./Resources/spy_30x_202201.txt")
# spy_jan_raw.to_csv("./Resources/spy_30x_202201.csv", index=None)

# %%
spy_jan_raw.head()

# %%
# Dropping all the PUT columns since it is not needed - how to get the last 2 rows back tho?

spy_jan_raw.drop(spy_jan_raw.iloc[:, 20:31], inplace = True , axis=1)

spy_jan_raw.tail()

# %%
spy_mar_raw = pd.read_csv("./Resources/spy_30x_202203.txt")
# spy_mar_raw.to_csv("./Resources/spy_30x_202203.csv", index=None)

# %%
# Dropping all the PUT columns since it is not needed - how to get the last 2 rows back tho?

spy_mar_raw.drop(spy_mar_raw.iloc[:, 20:31], inplace = True , axis=1)

spy_mar_raw.tail()

# %%
spy_data_raw = pd.concat([spy_jan_raw, spy_feb_raw, spy_mar_raw])

# %%
display(spy_data_raw.iloc[1380930:])

# %%
display(spy_data_raw.head())
display(spy_data_raw.tail())

# %%
#spy_data_v1 = spy_data_raw.drop(columns=["[QUOTE_UNIXTIME]", "[QUOTE_DATE]",  "[QUOTE_TIME_HOURS]', '[EXPIRE_UNIX]','[C_BID]', '[C_ASK]' , '[C_SIZE]'])

#spy_data_v2 = spy_data_raw.drop(columns=["[QUOTE_UNIXTIME]"," [QUOTE_DATE]", " [QUOTE_TIME_HOURS]", " [EXPIRE_UNIX]", " [C_BID]", " [C_ASK]", " [C_SIZE]"])

spy_data_raw.columns

# %%
spy_data_v2 = spy_data_raw.drop(columns=["[QUOTE_UNIXTIME]"," [QUOTE_DATE]", " [QUOTE_TIME_HOURS]", " [EXPIRE_UNIX]", " [C_BID]", " [C_ASK]", " [C_SIZE]"])

# %%
spy_data_v2.head()

# %%
# fixing the format of the column names 

spy_data_v2.rename(columns = {' [QUOTE_READTIME]': 'QUOTE_READTIME',' [UNDERLYING_LAST]': 'UNDERLYING_LAST', ' [EXPIRE_DATE]' : 'EXPIRE_DATE', ' [DTE]': 'DTE', ' [C_DELTA]' : 'C_DELTA', ' [C_GAMMA]' : 'C_GAMMA', ' [C_VEGA]': 'C_VEGA', ' [C_THETA]': 'C_THETA', ' [C_RHO]': 'C_RHO', ' [C_IV]': 'C_IV', ' [C_VOLUME]': 'C_VOLUME', ' [C_LAST]': 'C_LAST', ' [STRIKE]': 'STRIKE', ' [STRIKE_DISTANCE]': 'STRIKE_DISTANCE', ' [STRIKE_DISTANCE_PCT]': 'STRIKE_DISTANCE_PCT'}, inplace = True)

# %%
spy_data_v2.columns

# %%
spy_data_v2.head()

# %%
spy_data_v2['STRIKE DISTANCE'] = spy_data_v2['STRIKE'] - spy_data_v2['UNDERLYING_LAST']

display(spy_data_v2.head())

# %%
spy_data_v3 = spy_data_v2.drop(columns=['STRIKE_DISTANCE'])
spy_data_v3.head()

# %%
spy_data_v3 = spy_data_v3[
    (spy_data_v3['DTE'] <= 5) 
]

spy_data_v3.head()

# %%
# combine strike and expire date to make a unique identifier
spy_data_v3['CONTRACT'] = spy_data_v3['STRIKE'].astype(str) + spy_data_v3['EXPIRE_DATE']
spy_data_v3

# %%
#spy_data_v3 = spy_data_v3.set_index('CONTRACT')

# %%
spy_data_v3.head()

# %%
# setting the index to the contract readtime  

# spy_data_v4 = spy_data_v3.set_index('QUOTE_READTIME')

# %%
inception = spy_data_v3[(spy_data_v3['STRIKE DISTANCE'] <= 15.00) & (spy_data_v3['STRIKE DISTANCE'] > -3.00)]

# %%
inception_filtered = inception.loc[inception['DTE'] == 4.27]

# %%
inception_filtered

# %%
criteria_list = inception_filtered["CONTRACT"]

# %%
criteria_list.count()

# %%
spy_data_v4 = spy_data_v3[spy_data_v3["CONTRACT"].isin(criteria_list)]

# %%
spy_data_v4.count()

# %%
spy_data_v4.iloc[4673]

# %%
spy_data_v4.dtypes

# %%
spy_data_v4['C_IV'] = pd.to_numeric(spy_data_v4['C_IV'], errors = 'coerce')
spy_data_v4['C_LAST'] = pd.to_numeric(spy_data_v4['C_LAST'], errors = 'coerce')
spy_data_v4['C_VOLUME'] = pd.to_numeric(spy_data_v4['C_VOLUME'], errors = 'coerce')

# %%
spy_data_v4.dtypes

# %%
spy_data_v4.to_csv("./Resources/spycallsX1.csv", index=None)

# %% [markdown]
# # Start Here ____ SKIP AS OF 7/3/2022

# %%
import pandas as pd 
import numpy as np 
from pathlib import Path

# %%
# spy_path = Path('./Resources/spycallsV9.csv')
# spy_data_v5 = pd.read_csv(spy_path)

# %%
# spy_data_v5.tail()

# %%
# spy_data_v6 = spy_data_v5[
  #  (spy_data_v5['DTE'] <= 11.0) 
# ]

# spy_data_v6.head()

# %%
# combine strike and expire date to make a unique identifier
# spy_data_v6['CONTRACT'] = spy_data_v6['STRIKE'].astype(str) + spy_data_v6['EXPIRE_DATE']
# spy_data_v6

# %%
# spy_data_v6.to_csv("./Resources/spycallsV4.csv", index=None)

# %% [markdown]
# ## Start here using Optyxdata.csv 7/5

# %%
import pandas as pd 
import numpy as np 
from pathlib import Path

# %%
spy_path = Path('./Resources/optyxdata.csv')
spy_data_SC = pd.read_csv(spy_path)

# %%
spy_data_v7 = spy_data_SC.set_index('CONTRACT')

# %%
spy_data_v7

# %% [markdown]
# # __*PLAYING WITH CONTINUAL APPROACH (AS OPPOSED TO ONLY DTE4.27)*__

# %%
continual = spy_data_v7.copy()

# %%
#NOTE: CUT THIS OUT BECAUSE WE DO NOT CARE ABOUT WHAT HAPPENED DTE4.27 W/ CONTINUAL APPROACH

#mon_morn["PRICEOPEN"] = mon_morn.loc[mon_morn['DTE'] == 4.27, 'C_LAST']
#mon_morn.head(10)

# %%
continual["PRICECLOSE"] = continual.loc[continual['DTE'] == 2.0, 'C_LAST']
continual.head()

# %%
continual['ROI3'] = continual["PRICECLOSE"] / continual['C_LAST']
continual.head()

# %%
continual['ROI %'] = (continual['ROI3'] - 1) * 100
continual.head(100)

# %%
continual = continual.drop(columns=['ROI3'])
continual.head()

# %%
continual.loc[continual["ROI %"] <= -60, "y"] = 0
continual.loc[(continual["ROI %"] <= -10) & (continual["ROI %"] > -60), "y"] = 1
continual.loc[(continual["ROI %"] <= 10) & (continual["ROI %"] > -10), "y"] = 2
continual.loc[(continual["ROI %"] <= 60) & (continual["ROI %"] > 10), "y"] = 3
#spy_data_v7.loc[spy_data_v7["ROI %"] > 60, "y"] = 4
continual.loc[(continual["ROI %"] > 60) & (continual["ROI %"] < 100), "y"] = 4
continual.loc[continual["ROI %"] >= 100, "y"] = 5

# %%
continual["y"].value_counts()

# %%
continual.rename(columns = {'UNDERLYING_LAST': 'SPY PRICE'}, inplace = True)
continual.head()

# %%
continual.reset_index(inplace=True)

# %%
continual = continual.set_index('QUOTE_READTIME')
continual.head()

# %%
# Importing Vix Data 

vix_path = Path('./Resources/vixprice.csv')
vix_df = pd.read_csv(vix_path)
vix_df.rename(columns = {' [QUOTE_READTIME]': 'QUOTE_READTIME',' [UNDERLYING_LAST]': 'VIX PRICE'}, inplace = True)

# %%
vix_df1 = vix_df.drop_duplicates()

# %%
vix_df1.head()

# %%
vix_df1 = vix_df1.set_index('QUOTE_READTIME')

# %%
vix_df1.index = pd.to_datetime(vix_df1.index, infer_datetime_format=True)
vix_df1

# %%
continual.index = pd.to_datetime(continual.index, infer_datetime_format=True)
continual.head()

# %%
#NOTE: CUT THIS OUT BECAUSE IT APPLIES TO A MONDAY MORNING AT 9:30AM APPROACH ONLY!

#mon_morn_only = mon_morn.loc[mon_morn['DTE'] == 4.27]

# %%
vix_spy_continual = continual.merge(vix_df1, on='QUOTE_READTIME')

# %%
vix_spy_continual.head()

# %%
vix_spy_continual.shape

# %%
vix_spy_continual.head()

# %%
# vix_spy_continual.to_csv("./Resources/vix_spy_cont.csv", index=True)

# %% [markdown]
# # Shortcut for 7/5/2022 with inflation data

# %% [markdown]
# spy_path = Path('./Resources/vix_spy_continual_inf.csv')
# spy_data_SC2 = pd.read_csv(spy_path)
# vix_spy_continual = spy_data_SC2
# vix_spy_continual.head()

# %% [markdown]
# # Adding sentiment data

# %%
# Import Sentiment 
sent_path = Path('./Resources/sentimentdata.csv')
sent_df = pd.read_csv(sent_path)
# vix_df.rename(columns = {' [QUOTE_READTIME]': 'QUOTE_READTIME',' [UNDERLYING_LAST]': 'VIX PRICE'}, inplace = True)
sent_df.rename(columns = {'new_date_column': 'QUOTE_READTIME', 'average compound score per date': 'AVG SCORE','median compound score per date': 'MED SCORE','Sentiment Indicator Average Numerical': 'SEN IND AVG NUM','Sentiment Indicator Median Numerical': 'SEN IND MED NUM' }, inplace = True)
# sent_df= sent_df.set_index('QUOTE_READTIME')
# sent_df.index = pd.to_datetime(sent_df.index, infer_datetime_format=True)
sent_df.head()

# %%
vix_spy_continual.reset_index(inplace=True)
vix_spy_continual.head()

# %%
vix_spy_continual['QUOTE_READTIME'] = pd.to_datetime(vix_spy_continual['QUOTE_READTIME'])
sent_df['QUOTE_READTIME'] = pd.to_datetime(sent_df['QUOTE_READTIME'])
vix_spy_continual.sort_values('QUOTE_READTIME', inplace=True)
sent_df.sort_values('QUOTE_READTIME', inplace=True)

full_df = pd.merge_asof(vix_spy_continual, sent_df, on='QUOTE_READTIME')
full_df.head()

# %%
full_df.drop(columns=["Sentiment Indicator Median"], inplace=True)

# %%
full_df.drop(columns=["Sentiment Indicator Average"], inplace=True)

# %%
full_df.drop(columns=["CONTRACT"], inplace=True)

# %%
#full_df.drop(columns=["QUOTE_READTIME"], inplace=True)

# %%
full_df.to_csv("./Resources/full_df.csv", index=True)

# %% [markdown]
# # __*START HERE 07/06*__

# %%
import pandas as pd 
import numpy as np 
from pathlib import Path

# %%
spy_path = Path('./Resources/full_df.csv')
df = pd.read_csv(spy_path)
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df = df.set_index(["QUOTE_READTIME"])

# %%
test = df.iloc[9136:12227]
test
# Out:
#                      SPY PRICE EXPIRE_DATE   DTE  C_DELTA  C_GAMMA   C_VEGA  \
# QUOTE_READTIME
# 2022-02-21 09:30:00     434.23   2/25/2022  4.27  0.29772  0.02267  0.17496
# 2022-02-21 09:30:00     434.23   2/25/2022  4.27  0.12292  0.01574  0.10295
# 2022-02-21 09:30:00     434.23   2/25/2022  4.27  0.14455  0.01720  0.11533
# 2022-02-21 09:30:00     434.23   2/25/2022  4.27  0.16844  0.01845  0.12765
# 2022-02-21 09:30:00     434.23   2/25/2022  4.27  0.19250  0.01966  0.13832
# ...                        ...         ...   ...      ...      ...      ...
# 2022-03-09 10:30:00     425.75   3/11/2022  2.23  0.02690  0.00589  0.02389
# 2022-03-09 10:30:00     425.75   3/11/2022  2.23  0.17036  0.02286  0.09679
# 2022-03-09 10:30:00     425.75   3/11/2022  2.23  0.38220  0.03156  0.14647
# 2022-03-09 10:30:00     425.75   3/11/2022  2.23  0.34955  0.03107  0.14182
# 2022-03-09 10:30:00     425.75   3/11/2022  2.23  0.31686  0.03017  0.13644
#
#                      C_THETA    C_RHO     C_IV  C_VOLUME  ...  \
# QUOTE_READTIME                                            ...
# 2022-02-21 09:30:00 -0.54945  0.01702  0.30221      5711  ...
# 2022-02-21 09:30:00 -0.25710  0.00761  0.25641      4281  ...
# 2022-02-21 09:30:00 -0.29728  0.00850  0.26197      3173  ...
# 2022-02-21 09:30:00 -0.34181  0.00992  0.26852      5880  ...
# 2022-02-21 09:30:00 -0.38435  0.01070  0.27431     20991  ...
# ...                      ...      ...      ...       ...  ...
# 2022-03-09 10:30:00 -0.07895  0.00125  0.27365       133  ...
# 2022-03-09 10:30:00 -0.44825  0.00602  0.29060       405  ...
# 2022-03-09 10:30:00 -0.78588  0.01212  0.31839       443  ...
# 2022-03-09 10:30:00 -0.74805  0.01154  0.31371      3460  ...
# 2022-03-09 10:30:00 -0.70937  0.01036  0.31000       546  ...
#
#                      STRIKE DISTANCE  INFLATION%  PRICECLOSE      ROI %    y  \
# QUOTE_READTIME
# 2022-02-21 09:30:00             6.77         0.6        0.10 -96.363636  0.0
# 2022-02-21 09:30:00            13.77         0.6        0.04 -94.936709  0.0
# 2022-02-21 09:30:00            12.77         0.6        0.04 -95.876289  0.0
# 2022-02-21 09:30:00            11.77         0.6        0.04 -96.638655  0.0
# 2022-02-21 09:30:00            10.77         0.6        0.04 -97.260274  0.0
# ...                              ...         ...         ...        ...  ...
# 2022-03-09 10:30:00            20.25         0.6        0.06 -45.454545  1.0
# 2022-03-09 10:30:00            10.25         0.6        0.96  -4.000000  2.0
# 2022-03-09 10:30:00             3.25         0.6        3.31   5.079365  2.0
# 2022-03-09 10:30:00             4.25         0.6        2.84   1.792115  2.0
# 2022-03-09 10:30:00             5.25         0.6        2.45   2.510460  2.0
#
#                      VIX PRICE  AVG SCORE  MED SCORE  SEN IND AVG NUM  \
# QUOTE_READTIME
# 2022-02-21 09:30:00      27.75  -0.082688        0.0                0
# 2022-02-21 09:30:00      27.75  -0.082688        0.0                0
# 2022-02-21 09:30:00      27.75  -0.082688        0.0                0
# 2022-02-21 09:30:00      27.75  -0.082688        0.0                0
# 2022-02-21 09:30:00      27.75  -0.082688        0.0                0
# ...                        ...        ...        ...              ...
# 2022-03-09 10:30:00      32.38   0.100884        0.0                0
# 2022-03-09 10:30:00      32.38   0.100884        0.0                0
# 2022-03-09 10:30:00      32.38   0.100884        0.0                0
# 2022-03-09 10:30:00      32.38   0.100884        0.0                0
# 2022-03-09 10:30:00      32.38   0.100884        0.0                0
#
#                      SEN IND MED NUM
# QUOTE_READTIME
# 2022-02-21 09:30:00                0
# 2022-02-21 09:30:00                0
# 2022-02-21 09:30:00                0
# 2022-02-21 09:30:00                0
# 2022-02-21 09:30:00                0
# ...                              ...
# 2022-03-09 10:30:00                0
# 2022-03-09 10:30:00                0
# 2022-03-09 10:30:00                0
# 2022-03-09 10:30:00                0
# 2022-03-09 10:30:00                0
#
# [3091 rows x 23 columns]

# %%
train1 = df.iloc[:9136]
train1
# Out:
#                      SPY PRICE EXPIRE_DATE   DTE  C_DELTA  C_GAMMA   C_VEGA  \
# QUOTE_READTIME
# 2022-01-03 09:30:00     476.43    1/7/2022  4.27  0.62598  0.05055  0.21136
# 2022-01-03 09:30:00     476.43    1/7/2022  4.27  0.01171  0.00474  0.01717
# 2022-01-03 09:30:00     476.43    1/7/2022  4.27  0.01569  0.00635  0.02257
# 2022-01-03 09:30:00     476.43    1/7/2022  4.27  0.02331  0.00888  0.03151
# 2022-01-03 09:30:00     476.43    1/7/2022  4.27  0.02852  0.01072  0.03713
# ...                        ...         ...   ...      ...      ...      ...
# 2022-02-18 16:00:00     434.16   2/18/2022  0.00  0.00337  0.00253  0.00215
# 2022-02-18 16:00:00     434.16   2/18/2022  0.00  0.00477  0.00493  0.00283
# 2022-02-18 16:00:00     434.16   2/18/2022  0.00  0.00423  0.00407  0.00218
# 2022-02-18 16:00:00     434.16   2/18/2022  0.00  0.00441  0.00339  0.00265
# 2022-02-18 16:00:00     434.16   2/18/2022  0.00  0.00595  0.00620  0.00349
#
#                      C_THETA    C_RHO     C_IV  C_VOLUME  ...  \
# QUOTE_READTIME                                            ...
# 2022-01-03 09:30:00 -0.28773  0.03788  0.13515         1  ...
# 2022-01-03 09:30:00 -0.01484  0.00056  0.11400         0  ...
# 2022-01-03 09:30:00 -0.01973  0.00132  0.11196         0  ...
# 2022-01-03 09:30:00 -0.02878  0.00105  0.11290         0  ...
# 2022-01-03 09:30:00 -0.03303  0.00202  0.10768         0  ...
# ...                      ...      ...      ...       ...  ...
# 2022-02-18 16:00:00 -0.00451 -0.00044  0.22479      7586  ...
# 2022-02-18 16:00:00 -0.00548 -0.00044  0.15578     28707  ...
# 2022-02-18 16:00:00 -0.00484 -0.00031  0.17391     15790  ...
# 2022-02-18 16:00:00 -0.00477 -0.00016  0.19038     22622  ...
# 2022-02-18 16:00:00 -0.00499  0.00047  0.13854     27087  ...
#
#                      STRIKE DISTANCE  INFLATION%  PRICECLOSE         ROI %  \
# QUOTE_READTIME
# 2022-01-03 09:30:00            -2.43         0.8        0.55    -87.089202
# 2022-01-03 09:30:00            14.57         0.8        0.01      0.000000
# 2022-01-03 09:30:00            13.57         0.8        0.02      0.000000
# 2022-01-03 09:30:00            12.57         0.8        0.01    -66.666667
# 2022-01-03 09:30:00            11.57         0.8        0.01    -75.000000
# ...                              ...         ...         ...           ...
# 2022-02-18 16:00:00            11.84         0.6        3.27  32600.000000
# 2022-02-18 16:00:00             7.84         0.6        5.99  59800.000000
# 2022-02-18 16:00:00             8.84         0.6        5.26  52500.000000
# 2022-02-18 16:00:00             9.84         0.6        4.51  45000.000000
# 2022-02-18 16:00:00             6.84         0.6        7.46  74500.000000
#
#                        y  VIX PRICE  AVG SCORE  MED SCORE  SEN IND AVG NUM  \
# QUOTE_READTIME
# 2022-01-03 09:30:00  0.0      17.68   0.196649     0.0258                0
# 2022-01-03 09:30:00  2.0      17.68   0.196649     0.0258                0
# 2022-01-03 09:30:00  2.0      17.68   0.196649     0.0258                0
# 2022-01-03 09:30:00  0.0      17.68   0.196649     0.0258                0
# 2022-01-03 09:30:00  0.0      17.68   0.196649     0.0258                0
# ...                  ...        ...        ...        ...              ...
# 2022-02-18 16:00:00  5.0      28.09  -0.154929     0.0000                0
# 2022-02-18 16:00:00  5.0      28.09  -0.154929     0.0000                0
# 2022-02-18 16:00:00  5.0      28.09  -0.154929     0.0000                0
# 2022-02-18 16:00:00  5.0      28.09  -0.154929     0.0000                0
# 2022-02-18 16:00:00  5.0      28.09  -0.154929     0.0000                0
#
#                      SEN IND MED NUM
# QUOTE_READTIME
# 2022-01-03 09:30:00                0
# 2022-01-03 09:30:00                0
# 2022-01-03 09:30:00                0
# 2022-01-03 09:30:00                0
# 2022-01-03 09:30:00                0
# ...                              ...
# 2022-02-18 16:00:00                0
# 2022-02-18 16:00:00                0
# 2022-02-18 16:00:00                0
# 2022-02-18 16:00:00                0
# 2022-02-18 16:00:00                0
#
# [9136 rows x 23 columns]

# %%
train2 = df.iloc[12228:]
train2
# Out:
#                      SPY PRICE EXPIRE_DATE   DTE  C_DELTA  C_GAMMA   C_VEGA  \
# QUOTE_READTIME
# 2022-03-09 10:30:00     425.75   3/11/2022  2.23  0.25470  0.02784  0.12244
# 2022-03-09 10:30:00     425.75   3/11/2022  2.23  0.22447  0.02632  0.11483
# 2022-03-09 10:30:00     425.75   3/11/2022  2.23  0.19676  0.02465  0.10634
# 2022-03-09 10:30:00     425.75   3/11/2022  2.23  0.28433  0.02920  0.12999
# 2022-03-09 11:00:00     426.58   3/11/2022  2.21  0.02877  0.00647  0.02513
# ...                        ...         ...   ...      ...      ...      ...
# 2022-03-25 16:00:00     452.55   3/25/2022  0.00  1.00000  0.00000  0.00000
# 2022-03-25 16:00:00     452.55   3/25/2022  0.00  1.00000  0.00000  0.00000
# 2022-03-25 16:00:00     452.55   3/25/2022  0.00  0.00476  0.00494  0.00258
# 2022-03-25 16:00:00     452.55   3/25/2022  0.00  1.00000  0.00000  0.00000
# 2022-03-25 16:00:00     452.55   3/25/2022  0.00  0.00503  0.00398  0.00258
#
#                      C_THETA    C_RHO     C_IV  C_VOLUME  ...  \
# QUOTE_READTIME                                            ...
# 2022-03-09 10:30:00 -0.61224  0.00835  0.30157       253  ...
# 2022-03-09 10:30:00 -0.55976  0.00759  0.29823      1008  ...
# 2022-03-09 10:30:00 -0.50392  0.00693  0.29359      1246  ...
# 2022-03-09 10:30:00 -0.66041  0.00968  0.30499      1201  ...
# 2022-03-09 11:00:00 -0.08566  0.00125  0.26874       158  ...
# ...                      ...      ...      ...       ...  ...
# 2022-03-25 16:00:00  0.00000  0.00000      NaN       461  ...
# 2022-03-25 16:00:00  0.00000  0.00000      NaN       286  ...
# 2022-03-25 16:00:00 -0.00533  0.00014  0.16389      2702  ...
# 2022-03-25 16:00:00  0.00000  0.00000      NaN     18221  ...
# 2022-03-25 16:00:00 -0.00451 -0.00019  0.18157      3424  ...
#
#                      STRIKE DISTANCE  INFLATION%  PRICECLOSE       ROI %    y  \
# QUOTE_READTIME
# 2022-03-09 10:30:00             7.25         0.6        1.76   -1.123596  2.0
# 2022-03-09 10:30:00             8.25         0.6        1.48   10.447761  3.0
# 2022-03-09 10:30:00             9.25         0.6        1.19   -2.459016  2.0
# 2022-03-09 10:30:00             6.25         0.6        2.05   -0.966184  2.0
# 2022-03-09 11:00:00            19.42         0.6        0.06  -40.000000  1.0
# ...                              ...         ...         ...         ...  ...
# 2022-03-25 16:00:00            -9.55         0.8        3.38  -62.234637  0.0
# 2022-03-25 16:00:00           -10.55         0.8        4.07  -59.462151  1.0
# 2022-03-25 16:00:00             5.45         0.8        0.04  300.000000  5.0
# 2022-03-25 16:00:00            -3.55         0.8        0.86  -73.619632  0.0
# 2022-03-25 16:00:00             6.45         0.8        0.03  200.000000  5.0
#
#                      VIX PRICE  AVG SCORE  MED SCORE  SEN IND AVG NUM  \
# QUOTE_READTIME
# 2022-03-09 10:30:00      32.38   0.100884        0.0                0
# 2022-03-09 10:30:00      32.38   0.100884        0.0                0
# 2022-03-09 10:30:00      32.38   0.100884        0.0                0
# 2022-03-09 10:30:00      32.38   0.100884        0.0                0
# 2022-03-09 11:00:00      32.06   0.100884        0.0                0
# ...                        ...        ...        ...              ...
# 2022-03-25 16:00:00      20.84   0.129276        0.0                0
# 2022-03-25 16:00:00      20.84   0.129276        0.0                0
# 2022-03-25 16:00:00      20.84   0.129276        0.0                0
# 2022-03-25 16:00:00      20.84   0.129276        0.0                0
# 2022-03-25 16:00:00      20.84   0.129276        0.0                0
#
#                      SEN IND MED NUM
# QUOTE_READTIME
# 2022-03-09 10:30:00                0
# 2022-03-09 10:30:00                0
# 2022-03-09 10:30:00                0
# 2022-03-09 10:30:00                0
# 2022-03-09 11:00:00                0
# ...                              ...
# 2022-03-25 16:00:00                0
# 2022-03-25 16:00:00                0
# 2022-03-25 16:00:00                0
# 2022-03-25 16:00:00                0
# 2022-03-25 16:00:00                0
#
# [3226 rows x 23 columns]

# %%
train = pd.concat([train1, train2], axis=0)

# %%
train
# Out:
#                      SPY PRICE EXPIRE_DATE   DTE  C_DELTA  C_GAMMA   C_VEGA  \
# QUOTE_READTIME
# 2022-01-03 09:30:00     476.43    1/7/2022  4.27  0.62598  0.05055  0.21136
# 2022-01-03 09:30:00     476.43    1/7/2022  4.27  0.01171  0.00474  0.01717
# 2022-01-03 09:30:00     476.43    1/7/2022  4.27  0.01569  0.00635  0.02257
# 2022-01-03 09:30:00     476.43    1/7/2022  4.27  0.02331  0.00888  0.03151
# 2022-01-03 09:30:00     476.43    1/7/2022  4.27  0.02852  0.01072  0.03713
# ...                        ...         ...   ...      ...      ...      ...
# 2022-03-25 16:00:00     452.55   3/25/2022  0.00  1.00000  0.00000  0.00000
# 2022-03-25 16:00:00     452.55   3/25/2022  0.00  1.00000  0.00000  0.00000
# 2022-03-25 16:00:00     452.55   3/25/2022  0.00  0.00476  0.00494  0.00258
# 2022-03-25 16:00:00     452.55   3/25/2022  0.00  1.00000  0.00000  0.00000
# 2022-03-25 16:00:00     452.55   3/25/2022  0.00  0.00503  0.00398  0.00258
#
#                      C_THETA    C_RHO     C_IV  C_VOLUME  ...  \
# QUOTE_READTIME                                            ...
# 2022-01-03 09:30:00 -0.28773  0.03788  0.13515         1  ...
# 2022-01-03 09:30:00 -0.01484  0.00056  0.11400         0  ...
# 2022-01-03 09:30:00 -0.01973  0.00132  0.11196         0  ...
# 2022-01-03 09:30:00 -0.02878  0.00105  0.11290         0  ...
# 2022-01-03 09:30:00 -0.03303  0.00202  0.10768         0  ...
# ...                      ...      ...      ...       ...  ...
# 2022-03-25 16:00:00  0.00000  0.00000      NaN       461  ...
# 2022-03-25 16:00:00  0.00000  0.00000      NaN       286  ...
# 2022-03-25 16:00:00 -0.00533  0.00014  0.16389      2702  ...
# 2022-03-25 16:00:00  0.00000  0.00000      NaN     18221  ...
# 2022-03-25 16:00:00 -0.00451 -0.00019  0.18157      3424  ...
#
#                      STRIKE DISTANCE  INFLATION%  PRICECLOSE       ROI %    y  \
# QUOTE_READTIME
# 2022-01-03 09:30:00            -2.43         0.8        0.55  -87.089202  0.0
# 2022-01-03 09:30:00            14.57         0.8        0.01    0.000000  2.0
# 2022-01-03 09:30:00            13.57         0.8        0.02    0.000000  2.0
# 2022-01-03 09:30:00            12.57         0.8        0.01  -66.666667  0.0
# 2022-01-03 09:30:00            11.57         0.8        0.01  -75.000000  0.0
# ...                              ...         ...         ...         ...  ...
# 2022-03-25 16:00:00            -9.55         0.8        3.38  -62.234637  0.0
# 2022-03-25 16:00:00           -10.55         0.8        4.07  -59.462151  1.0
# 2022-03-25 16:00:00             5.45         0.8        0.04  300.000000  5.0
# 2022-03-25 16:00:00            -3.55         0.8        0.86  -73.619632  0.0
# 2022-03-25 16:00:00             6.45         0.8        0.03  200.000000  5.0
#
#                      VIX PRICE  AVG SCORE  MED SCORE  SEN IND AVG NUM  \
# QUOTE_READTIME
# 2022-01-03 09:30:00      17.68   0.196649     0.0258                0
# 2022-01-03 09:30:00      17.68   0.196649     0.0258                0
# 2022-01-03 09:30:00      17.68   0.196649     0.0258                0
# 2022-01-03 09:30:00      17.68   0.196649     0.0258                0
# 2022-01-03 09:30:00      17.68   0.196649     0.0258                0
# ...                        ...        ...        ...              ...
# 2022-03-25 16:00:00      20.84   0.129276     0.0000                0
# 2022-03-25 16:00:00      20.84   0.129276     0.0000                0
# 2022-03-25 16:00:00      20.84   0.129276     0.0000                0
# 2022-03-25 16:00:00      20.84   0.129276     0.0000                0
# 2022-03-25 16:00:00      20.84   0.129276     0.0000                0
#
#                      SEN IND MED NUM
# QUOTE_READTIME
# 2022-01-03 09:30:00                0
# 2022-01-03 09:30:00                0
# 2022-01-03 09:30:00                0
# 2022-01-03 09:30:00                0
# 2022-01-03 09:30:00                0
# ...                              ...
# 2022-03-25 16:00:00                0
# 2022-03-25 16:00:00                0
# 2022-03-25 16:00:00                0
# 2022-03-25 16:00:00                0
# 2022-03-25 16:00:00                0
#
# [12362 rows x 23 columns]

# %%
train.to_csv("./Resources/train.csv", index=True)

# %%
test.to_csv("./Resources/test.csv", index=True)

# %%
#Inflation Data 
# Nov - 0.8% - For dec-jan
# Dec +0.5% - For jan-feb
# Jan +0.6% - For feb-march
# Feb +0.8% - for March-april

# %% [markdown]
# ## Y Classification

# %% [markdown]
# # Create a 'y' column for our % profit/loss categories (0,1,2,3,4)
# # in % terms
# # 0 is <-60 = strong sell
# # 1 is (>-60 to -10) = sell
# # 2 is (>-10 to 10) = pass
# # 3 is (>10-60) = buy
# # 4 is >60 to <80 = strong buy
# # 5 is <100 = high return
